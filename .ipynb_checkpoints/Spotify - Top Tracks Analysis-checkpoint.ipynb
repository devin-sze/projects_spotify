# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import date

# %% [markdown]
# resp = requests.get('https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl')
# resp

# %% [markdown]
# resp = requests.get(
#     url='https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy',
#     params={
#         'Accept': 'application/json',
#         'Content-Type': 'application/json',
#         'Authorization': 'Bearer BQA-8l75uXYmLRSO_FJ65UFnVt8WY7W4wNye14ipSd7zTB34BRAEDdFycjf-yCky00OMBD-r4L7ZGhjTuhCczZJm9d3v3C_s2KGTNqT5DsZmYCHciXNeLoNT3n2_Yhkr-f25myvSOZ1oqHbfEnIpLF69m2BHL56reQ_ZgXTR'
#     }
# )
# resp.json()

# %% [markdown]
# TOKEN = 'BQA-8l75uXYmLRSO_FJ65UFnVt8WY7W4wNye14ipSd7zTB34BRAEDdFycjf-yCky00OMBD-r4L7ZGhjTuhCczZJm9d3v3C_s2KGTNqT5DsZmYCHciXNeLoNT3n2_Yhkr-f25myvSOZ1oqHbfEnIpLF69m2BHL56reQ_ZgXTR'
# BASE_URL = 'https://api.spotify.com/v1/'
# headers = {
#     'Authorization': 'Bearer '+ TOKEN
# }
#
# console = 'albums'
# track_id = '4aawyAB9vmqN3uQ7FjRGTy'
#
# resp = requests.get(
#     url = BASE_URL + console + '/' + track_id,
#     headers = headers
# )
# resp.json()

# %% [markdown]
# TOKEN = 'BQA-8l75uXYmLRSO_FJ65UFnVt8WY7W4wNye14ipSd7zTB34BRAEDdFycjf-yCky00OMBD-r4L7ZGhjTuhCczZJm9d3v3C_s2KGTNqT5DsZmYCHciXNeLoNT3n2_Yhkr-f25myvSOZ1oqHbfEnIpLF69m2BHL56reQ_ZgXTR'
# BASE_URL = 'https://api.spotify.com/v1/'
# headers = {
#     'Authorization': 'Bearer '+ TOKEN
# }
#
# console = 'artists'
# _id = '2CIMQHirSU0MQqyYHq0eOx%2C57dN52uHvrHOxijzpIgu3E%2C1vCWHaC5f2uS3yhpwWbIA6'
#
# resp = requests.get(
#     url = 'https://api.spotify.com/v1/artists?ids=2CIMQHirSU0MQqyYHq0eOx%2C57dN52uHvrHOxijzpIgu3E%2C1vCWHaC5f2uS3yhpwWbIA6',#BASE_URL + console + '/' + _id,
#     headers = headers
# )
# r = resp.json()
# r.get("artists")

# %%
TOKEN = 'BQB96x-cxU25olOg8OdbaYGPpAu6DB6r9AEofd5qcPOrfaKbcYaHxyhnrpQGipZVxl14df3CH4IcCP3eXGKEiv2uAZ6RmLVIXU6hTFSaQbZk8Kf5RJCLnoH6yOI5jiBEnYH0hXahyrxJfzksXAckWyYmxQ_YR182MJiWOSwE'
BASE_URL = 'https://api.spotify.com/v1/'
headers = {
    'Authorization': 'Bearer '+ TOKEN
}

console = 'artists'
_id = '2CIMQHirSU0MQqyYHq0eOx%2C57dN52uHvrHOxijzpIgu3E%2C1vCWHaC5f2uS3yhpwWbIA6'



resp = requests.get(
    url = 'https://api.spotify.com/v1/playlists/37i9dQZEVXbLiRSasKsNU9',#viral 50
    #url = 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF',#top 50
    headers = headers
)
r = resp.json()
top_tracks = r.get('tracks').get("items")

# %% [markdown]
# top_tracks[0].get("track").get("album").get("id")
# top_tracks[0].get("track").get("album").get("name")
# top_tracks[0].get("track").get("album").get("release_date")
# top_tracks[0].get("track").get("album").get("total_tracks")
#
# len(top_tracks[0].get("track").get("album").get("artists"))
# len(top_tracks[0].get("track").get("album").get("available_markets"))
#
# x = top_tracks[5].get("track").get("album").get("artists")
# [elem.get("name") for elem in x]

# %% [markdown]
# artists = []
#
# for i in range(len(top_tracks)):
#     x = top_tracks[i].get("track").get("album").get("artists")
#     art = [elem.get("name") for elem in x]
#     #print(art)
#     artists += [art]
#
# print(artists)

# %% [markdown]
# len(top_tracks)

# %% [markdown]
# ### Initialize
# Create the dataframe

# %%
df = pd.DataFrame()

# %% [markdown]
# ### Album
# First, create the necessary for functions extracting the album information
#
# Next, actually extract the album information and place it into the dataframe

# %%
def extract_album(json, key):
    return [json[i].get("track").get("album").get(key) for i in range(len(json))]
def extract_album_len(json, key):
    return [len(json[i].get("track").get("album").get(key))for i in range(len(json))]
def extract_album_artists(json, key="artists"):
    artists = []

    for i in range(len(json)):
        x = json[i].get("track").get("album").get("artists")
        art = [elem.get("name") for elem in x]
        artists += [art]
    return artists

# %%
def df_album(df, tracks):
    basic_album_keys = ["id", "name", "release_date", "total_tracks"]
    for key in basic_album_keys:
        df["album, " + key] = extract_album(tracks, key)

    len_keys = ["artists", "available_markets"]
    for key in len_keys:
        df["album, len " + key] = extract_album_len(tracks, key)

    df["album, artists"] = extract_album_artists(tracks)
    
    return df
df = df_album(df, top_tracks)
df
# Out:
#                  album, id                                        album, name  \
# 0   4AQOhI7QMKq9vmHuzduPRk                                               SHUM
# 1   7KF1Ain9mYYlg5M46g0i4A                              Teatro d'ira - Vol. I
# 2   6o4JpkccU6eGejGBoUw88E                                  The Backyardigans
# 3   3e6HcRWTkyGi6dA0Zg5pxw                                        PHONKY TOWN
# 4   7KF1Ain9mYYlg5M46g0i4A                              Teatro d'ira - Vol. I
# 5   6yNuKzr4GNs1c7Kpdf7c5w                                Here's Your Perfect
# 6   3nxwixOHCqSre8Ycbuypqv                                         Fine Apple
# 7   7dg4laFCDLBu0Oi2uWyafE                                              Voilà
# 8   5gH9EDMWWiLEplNCLb1r7l                              Dick (feat. Doja Cat)
# 9   6Lzb7EjZXgtelxgBsZUhMS                                          Dark Side
# 10  7KF1Ain9mYYlg5M46g0i4A                              Teatro d'ira - Vol. I
# 11  1UnqlxXSM5dlxZi6vLIIEH                                     Tout l'univers
# 12  7r9c4LfF8fMsCiVtDWEvyJ                       Bundles (feat. Taylor Girlz)
# 13  68i0gDIA5T5YVUIxj9QdsU                                 #BrooklynBloodPop!
# 14  6rPU1BHqLneslZ1N1EvVdR                                   Are You Alright?
# 15  2qAJL1ffzMUKu3quKRoMwi                                          Mata Hari
# 16  1FBBji6E8EB4zBsTn6m8Ax                                        double take
# 17  2qJw6w5XwQO0PQlSWPu7Tw                                             Chosen
# 18  1WPqdSZcLnQQFhCGK3kJk6                                          Paraluman
# 19  1OfWh8e9R7tOmrX4pGlDBe                                         Discoteque
# 20  3ucQ8ogD2Li2U0rwkrdwlx  Body (Remix) [feat. ArrDee, E1 (3x3), ZT (3x3)...
# 21  0hddqJaLbuagDCHHSgULIm                                          El Diablo
# 22  6rPU1BHqLneslZ1N1EvVdR                                   Are You Alright?
# 23  44a7Wk3Jh2JGVhjcFYWozj                                Il ballo della vita
# 24  1ay9XEArx0arC0VBJ5hUn9                                        keepyousafe
# 25  2Zegz0LaKZgwrLo5UbEa2x                                           10 Years
# 26  6rPU1BHqLneslZ1N1EvVdR                                   Are You Alright?
# 27  1miTgxRTUje9Jqml1aOSUi                          Hot Sauce - The 1st Album
# 28  4LGYBcRsteiXjcPD4QQvxv                                  BORDER : CARNIVAL
# 29  4VZz15JGgc4DT0TTI9pPaz                                            Poblado
# 30  6s84u2TUpR3wdUv4NgKA2j                                               SOUR
# 31  6Ltrg0NAj6GqIyO2bjPgYI                                        Je me casse
# 32  6E8lxwX7KMAO9nCx4A5tAR                                                 TV
# 33  7jLvNAEap7DWqC6W5GC6nH                                  I Don't Feel Hate
# 34  5LEnyJ9RP1ZyVgvcKfpwd0                                      Melawan Restu
# 35  2sZzCGg7xCNdWQwoVaFuro                                             Plutão
# 36  58QwKbqqxvic4OsBubpZ6h                                            Fragile
# 37  2VnYbTdZ6uUSdCfh2UNNga                                               Pain
# 38  3MTd9EsYiU3IMfuSfVco3W                          Eu Sou O Mestre Dos Magos
# 39  4ar4zcVlbYDYKgq5wEdq0T  t r a n s p a r e n t s o u l feat. Travis Barker
# 40  7KF1Ain9mYYlg5M46g0i4A                              Teatro d'ira - Vol. I
# 41  6e5G83EOP9tEfklabpOhRp                                      RUSSIAN WOMAN
# 42  5KXv2MHeoLSqZ96jRuFF9H                                       Love Tonight
# 43  5WjaIWthUR3AjA0UYG3jR5                                             Freaks
# 44  44a7Wk3Jh2JGVhjcFYWozj                                Il ballo della vita
# 45  1iCDTyPPAevNAvqC6WFlRy                                            Bipolar
# 46  0pDplTjct8PBplJ7s2sL6p                                Samma gamla vanliga
# 47  0IzpAGRpjLqIQLt4FvmW7m              Black Out Days (Future Islands Remix)
# 48  1miTgxRTUje9Jqml1aOSUi                          Hot Sauce - The 1st Album
# 49  1OnzqJTL9bwe4kvaLxRYxt                           Kiss Me More (feat. SZA)
#
#    album, release_date  album, total_tracks  album, len artists  \
# 0           2021-03-10                    2                   1
# 1           2021-03-19                    8                   1
# 2           2005-07-12                   19                   1
# 3           2021-03-16                    1                   1
# 4           2021-03-19                    8                   1
# 5           2021-04-30                    4                   1
# 6           2021-05-28                    1                   1
# 7           2020-11-06                    1                   1
# 8           2021-04-23                    1                   1
# 9           2021-01-21                    1                   1
# 10          2021-03-19                    8                   1
# 11          2021-03-10                    1                   1
# 12          2021-05-05                    1                   2
# 13          2020-07-27                    1                   1
# 14          2021-05-08                    4                   1
# 15          2021-03-15                    1                   1
# 16          2019-05-24                    1                   1
# 17          2017-12-08                    7                   1
# 18          2021-03-26                    1                   1
# 19          2021-01-21                    1                   1
# 20          2021-04-22                    1                   3
# 21          2021-02-28                    1                   1
# 22          2021-05-08                    4                   1
# 23          2018-10-26                   12                   1
# 24          2020-01-10                    1                   1
# 25          2021-03-13                    1                   1
# 26          2021-05-08                    4                   1
# 27          2021-05-10                   10                   1
# 28          2021-04-26                    6                   1
# 29          2020-12-11                    1                   3
# 30          2021-05-21                   11                   1
# 31          2021-03-30                    1                   1
# 32          2021-05-20                   13                   1
# 33          2021-02-25                    1                   1
# 34          2021-03-26                    1                   1
# 35          2021-03-26                    1                   1
# 36          2021-04-30                   11                   1
# 37          2021-02-05                    1                   1
# 38          2021-03-01                    1                   1
# 39          2021-04-27                    1                   2
# 40          2021-03-19                    8                   1
# 41          2021-03-19                    1                   1
# 42          2017-12-14                    2                   1
# 43          2021-05-15                    1                   1
# 44          2018-10-26                   12                   1
# 45          2021-04-09                    1                   3
# 46          2021-04-09                    1                   1
# 47          2017-09-01                    1                   1
# 48          2021-05-10                   10                   1
# 49          2021-04-09                    1                   2
#
#     album, len available_markets                              album, artists
# 0                            177                                      [Go_A]
# 1                            178                                  [Måneskin]
# 2                            178                         [The Backyardigans]
# 3                            178                                [PlayaPhonk]
# 4                            178                                  [Måneskin]
# 5                            178                              [Jamie Miller]
# 6                            178                                     [Nic D]
# 7                            178                             [Barbara Pravi]
# 8                            178                                  [StarBoi3]
# 9                              1                             [Blind Channel]
# 10                           178                                  [Måneskin]
# 11                           178                              [Gjon's Tears]
# 12                           178                [Kayla Nicole, Taylor Girlz]
# 13                           178                                      [SyKo]
# 14                           178                                   [Lovejoy]
# 15                           178                                    [Efendi]
# 16                           178                                     [dhruv]
# 17                           178                                  [Måneskin]
# 18                           178                                      [Adie]
# 19                           178                                  [THE ROOP]
# 20                           178  [Tion Wayne, Russ Millions, Fivio Foreign]
# 21                           176                           [Elena Tsagrinou]
# 22                           178                                   [Lovejoy]
# 23                           178                                  [Måneskin]
# 24                           178                                     [Yahya]
# 25                           178                                [Daði Freyr]
# 26                           178                                   [Lovejoy]
# 27                           178                                 [NCT DREAM]
# 28                           178                                   [ENHYPEN]
# 29                           177   [Crissin, Totoy El Frio, Natan & Shander]
# 30                           178                            [Olivia Rodrigo]
# 31                           177                                   [Destiny]
# 32                             1                                [Tai Verdes]
# 33                           178                                   [Jendrik]
# 34                           178                                  [Mahalini]
# 35                           178                                       [VMZ]
# 36                           178                                     [eAeon]
# 37                           178                            [PinkPantheress]
# 38                           178                           [Various Artists]
# 39                           178                     [WILLOW, Travis Barker]
# 40                           178                                  [Måneskin]
# 41                           177                                   [Manizha]
# 42                           178                                    [Shouse]
# 43                           178                                [Surf Curse]
# 44                           178                                  [Måneskin]
# 45                           178         [Mc Davi, Mc Pedrinho, Mc Don Juan]
# 46                           178                                       [A36]
# 47                           177                                [Phantogram]
# 48                           178                                 [NCT DREAM]
# 49                           178                             [Doja Cat, SZA]

# %% [markdown]
# ### Track
# First, create the necessary for functions extracting the track information
#
# Next, actually extract the track information and place it into the dataframe

# %%
def extract_track(json, key):
    return [json[i].get("track").get(key) for i in range(len(json))]

def extract_track_artists(json, key="artists"):
    artists = []

    for i in range(len(json)):
        x = json[i].get("track").get("artists")
        art = [elem.get("name") for elem in x]
        artists += [art]
    return artists

# %%
def df_tracks(df, tracks):
    basic_track_keys = ["name", "popularity", "duration_ms", "explicit"]
    for key in basic_track_keys:
        df["track, " + key] = extract_track(tracks, key)

    df["track, artists"] = extract_track_artists(tracks)
    return df
df = df_tracks(df, top_tracks)

# %%
df
# Out:
#                  album, id                                        album, name  \
# 0   4AQOhI7QMKq9vmHuzduPRk                                               SHUM
# 1   7KF1Ain9mYYlg5M46g0i4A                              Teatro d'ira - Vol. I
# 2   6o4JpkccU6eGejGBoUw88E                                  The Backyardigans
# 3   3e6HcRWTkyGi6dA0Zg5pxw                                        PHONKY TOWN
# 4   7KF1Ain9mYYlg5M46g0i4A                              Teatro d'ira - Vol. I
# 5   6yNuKzr4GNs1c7Kpdf7c5w                                Here's Your Perfect
# 6   3nxwixOHCqSre8Ycbuypqv                                         Fine Apple
# 7   7dg4laFCDLBu0Oi2uWyafE                                              Voilà
# 8   5gH9EDMWWiLEplNCLb1r7l                              Dick (feat. Doja Cat)
# 9   6Lzb7EjZXgtelxgBsZUhMS                                          Dark Side
# 10  7KF1Ain9mYYlg5M46g0i4A                              Teatro d'ira - Vol. I
# 11  1UnqlxXSM5dlxZi6vLIIEH                                     Tout l'univers
# 12  7r9c4LfF8fMsCiVtDWEvyJ                       Bundles (feat. Taylor Girlz)
# 13  68i0gDIA5T5YVUIxj9QdsU                                 #BrooklynBloodPop!
# 14  6rPU1BHqLneslZ1N1EvVdR                                   Are You Alright?
# 15  2qAJL1ffzMUKu3quKRoMwi                                          Mata Hari
# 16  1FBBji6E8EB4zBsTn6m8Ax                                        double take
# 17  2qJw6w5XwQO0PQlSWPu7Tw                                             Chosen
# 18  1WPqdSZcLnQQFhCGK3kJk6                                          Paraluman
# 19  1OfWh8e9R7tOmrX4pGlDBe                                         Discoteque
# 20  3ucQ8ogD2Li2U0rwkrdwlx  Body (Remix) [feat. ArrDee, E1 (3x3), ZT (3x3)...
# 21  0hddqJaLbuagDCHHSgULIm                                          El Diablo
# 22  6rPU1BHqLneslZ1N1EvVdR                                   Are You Alright?
# 23  44a7Wk3Jh2JGVhjcFYWozj                                Il ballo della vita
# 24  1ay9XEArx0arC0VBJ5hUn9                                        keepyousafe
# 25  2Zegz0LaKZgwrLo5UbEa2x                                           10 Years
# 26  6rPU1BHqLneslZ1N1EvVdR                                   Are You Alright?
# 27  1miTgxRTUje9Jqml1aOSUi                          Hot Sauce - The 1st Album
# 28  4LGYBcRsteiXjcPD4QQvxv                                  BORDER : CARNIVAL
# 29  4VZz15JGgc4DT0TTI9pPaz                                            Poblado
# 30  6s84u2TUpR3wdUv4NgKA2j                                               SOUR
# 31  6Ltrg0NAj6GqIyO2bjPgYI                                        Je me casse
# 32  6E8lxwX7KMAO9nCx4A5tAR                                                 TV
# 33  7jLvNAEap7DWqC6W5GC6nH                                  I Don't Feel Hate
# 34  5LEnyJ9RP1ZyVgvcKfpwd0                                      Melawan Restu
# 35  2sZzCGg7xCNdWQwoVaFuro                                             Plutão
# 36  58QwKbqqxvic4OsBubpZ6h                                            Fragile
# 37  2VnYbTdZ6uUSdCfh2UNNga                                               Pain
# 38  3MTd9EsYiU3IMfuSfVco3W                          Eu Sou O Mestre Dos Magos
# 39  4ar4zcVlbYDYKgq5wEdq0T  t r a n s p a r e n t s o u l feat. Travis Barker
# 40  7KF1Ain9mYYlg5M46g0i4A                              Teatro d'ira - Vol. I
# 41  6e5G83EOP9tEfklabpOhRp                                      RUSSIAN WOMAN
# 42  5KXv2MHeoLSqZ96jRuFF9H                                       Love Tonight
# 43  5WjaIWthUR3AjA0UYG3jR5                                             Freaks
# 44  44a7Wk3Jh2JGVhjcFYWozj                                Il ballo della vita
# 45  1iCDTyPPAevNAvqC6WFlRy                                            Bipolar
# 46  0pDplTjct8PBplJ7s2sL6p                                Samma gamla vanliga
# 47  0IzpAGRpjLqIQLt4FvmW7m              Black Out Days (Future Islands Remix)
# 48  1miTgxRTUje9Jqml1aOSUi                          Hot Sauce - The 1st Album
# 49  1OnzqJTL9bwe4kvaLxRYxt                           Kiss Me More (feat. SZA)
#
#    album, release_date  album, total_tracks  album, len artists  \
# 0           2021-03-10                    2                   1
# 1           2021-03-19                    8                   1
# 2           2005-07-12                   19                   1
# 3           2021-03-16                    1                   1
# 4           2021-03-19                    8                   1
# 5           2021-04-30                    4                   1
# 6           2021-05-28                    1                   1
# 7           2020-11-06                    1                   1
# 8           2021-04-23                    1                   1
# 9           2021-01-21                    1                   1
# 10          2021-03-19                    8                   1
# 11          2021-03-10                    1                   1
# 12          2021-05-05                    1                   2
# 13          2020-07-27                    1                   1
# 14          2021-05-08                    4                   1
# 15          2021-03-15                    1                   1
# 16          2019-05-24                    1                   1
# 17          2017-12-08                    7                   1
# 18          2021-03-26                    1                   1
# 19          2021-01-21                    1                   1
# 20          2021-04-22                    1                   3
# 21          2021-02-28                    1                   1
# 22          2021-05-08                    4                   1
# 23          2018-10-26                   12                   1
# 24          2020-01-10                    1                   1
# 25          2021-03-13                    1                   1
# 26          2021-05-08                    4                   1
# 27          2021-05-10                   10                   1
# 28          2021-04-26                    6                   1
# 29          2020-12-11                    1                   3
# 30          2021-05-21                   11                   1
# 31          2021-03-30                    1                   1
# 32          2021-05-20                   13                   1
# 33          2021-02-25                    1                   1
# 34          2021-03-26                    1                   1
# 35          2021-03-26                    1                   1
# 36          2021-04-30                   11                   1
# 37          2021-02-05                    1                   1
# 38          2021-03-01                    1                   1
# 39          2021-04-27                    1                   2
# 40          2021-03-19                    8                   1
# 41          2021-03-19                    1                   1
# 42          2017-12-14                    2                   1
# 43          2021-05-15                    1                   1
# 44          2018-10-26                   12                   1
# 45          2021-04-09                    1                   3
# 46          2021-04-09                    1                   1
# 47          2017-09-01                    1                   1
# 48          2021-05-10                   10                   1
# 49          2021-04-09                    1                   2
#
#     album, len available_markets                              album, artists  \
# 0                            177                                      [Go_A]
# 1                            178                                  [Måneskin]
# 2                            178                         [The Backyardigans]
# 3                            178                                [PlayaPhonk]
# 4                            178                                  [Måneskin]
# 5                            178                              [Jamie Miller]
# 6                            178                                     [Nic D]
# 7                            178                             [Barbara Pravi]
# 8                            178                                  [StarBoi3]
# 9                              1                             [Blind Channel]
# 10                           178                                  [Måneskin]
# 11                           178                              [Gjon's Tears]
# 12                           178                [Kayla Nicole, Taylor Girlz]
# 13                           178                                      [SyKo]
# 14                           178                                   [Lovejoy]
# 15                           178                                    [Efendi]
# 16                           178                                     [dhruv]
# 17                           178                                  [Måneskin]
# 18                           178                                      [Adie]
# 19                           178                                  [THE ROOP]
# 20                           178  [Tion Wayne, Russ Millions, Fivio Foreign]
# 21                           176                           [Elena Tsagrinou]
# 22                           178                                   [Lovejoy]
# 23                           178                                  [Måneskin]
# 24                           178                                     [Yahya]
# 25                           178                                [Daði Freyr]
# 26                           178                                   [Lovejoy]
# 27                           178                                 [NCT DREAM]
# 28                           178                                   [ENHYPEN]
# 29                           177   [Crissin, Totoy El Frio, Natan & Shander]
# 30                           178                            [Olivia Rodrigo]
# 31                           177                                   [Destiny]
# 32                             1                                [Tai Verdes]
# 33                           178                                   [Jendrik]
# 34                           178                                  [Mahalini]
# 35                           178                                       [VMZ]
# 36                           178                                     [eAeon]
# 37                           178                            [PinkPantheress]
# 38                           178                           [Various Artists]
# 39                           178                     [WILLOW, Travis Barker]
# 40                           178                                  [Måneskin]
# 41                           177                                   [Manizha]
# 42                           178                                    [Shouse]
# 43                           178                                [Surf Curse]
# 44                           178                                  [Måneskin]
# 45                           178         [Mc Davi, Mc Pedrinho, Mc Don Juan]
# 46                           178                                       [A36]
# 47                           177                                [Phantogram]
# 48                           178                                 [NCT DREAM]
# 49                           178                             [Doja Cat, SZA]
#
#                                           track, name  track, popularity  \
# 0                                                SHUM                 80
# 1                               I WANNA BE YOUR SLAVE                 86
# 2                                           Castaways                 77
# 3                                         PHONKY TOWN                 79
# 4                                       ZITTI E BUONI                 85
# 5                                 Here's Your Perfect                 69
# 6                                          Fine Apple                 40
# 7                                               Voilà                 81
# 8                               Dick (feat. Doja Cat)                 86
# 9                                           Dark Side                 69
# 10                                           CORALINE                 80
# 11                                     Tout l'univers                 79
# 12                       Bundles (feat. Taylor Girlz)                 72
# 13                                 #BrooklynBloodPop!                 81
# 14                                            One Day                 81
# 15                                          Mata Hari                 77
# 16                                        double take                 74
# 17                                            Beggin'                 73
# 18                                          Paraluman                 66
# 19                                         Discoteque                 76
# 20  Body (Remix) [feat. ArrDee, E1 (3x3), ZT (3x3)...                 91
# 21                                          El Diablo                 50
# 22                                          Sex Sells                 77
# 23                                       Torna a casa                 77
# 24                                        keepyousafe                 68
# 25                                           10 Years                 79
# 26                                              Taunt                 78
# 27                                          Hot Sauce                 80
# 28                                              FEVER                 76
# 29                                            Poblado                 87
# 30                                            deja vu                 90
# 31                                        Je me casse                 77
# 32                                              A-O-K                 61
# 33                                  I Don't Feel Hate                 69
# 34                                      Melawan Restu                 68
# 35                                             Plutão                 71
# 36                                   Don't (feat. RM)                 76
# 37                                               Pain                 72
# 38                          Eu Sou O Mestre Dos Magos                 66
# 39  t r a n s p a r e n t s o u l feat. Travis Barker                 79
# 40                                      FOR YOUR LOVE                 73
# 41                                      RUSSIAN WOMAN                 75
# 42                                Love Tonight - Edit                 76
# 43                                             Freaks                 78
# 44                                       Morirò da Re                 75
# 45                                            Bipolar                 86
# 46                                Samma gamla vanliga                 73
# 47              Black Out Days - Future Islands Remix                 70
# 48                                      Dive Into You                 73
# 49                           Kiss Me More (feat. SZA)                 98
#
#     track, duration_ms  track, explicit  \
# 0               172675            False
# 1               173346            False
# 2                87706            False
# 3               141373             True
# 4               194786             True
# 5               158594            False
# 6               153296            False
# 7               176815            False
# 8               175238             True
# 9               177789            False
# 10              300413            False
# 11              183706            False
# 12              154805             True
# 13              145610            False
# 14              144616             True
# 15              160980            False
# 16              171743            False
# 17              211560            False
# 18              312320            False
# 19              180521            False
# 20              278085             True
# 21              181546            False
# 22              246536             True
# 23              230666            False
# 24              261673            False
# 25              166000            False
# 26              133779            False
# 27              195813            False
# 28              172106            False
# 29              201596            False
# 30              215506             True
# 31              178500            False
# 32              173640             True
# 33              176996            False
# 34              219896            False
# 35              221461            False
# 36              205386            False
# 37               98544            False
# 38              174826             True
# 39              168030             True
# 40              230706            False
# 41              176877            False
# 42              241970            False
# 43              147062            False
# 44              157880            False
# 45              276480             True
# 46              129985             True
# 47              248346            False
# 48              192826            False
# 49              208866             True
#
#                                        track, artists
# 0                                              [Go_A]
# 1                                          [Måneskin]
# 2                                 [The Backyardigans]
# 3                                        [PlayaPhonk]
# 4                                          [Måneskin]
# 5                                      [Jamie Miller]
# 6                                             [Nic D]
# 7                                     [Barbara Pravi]
# 8                                [StarBoi3, Doja Cat]
# 9                                     [Blind Channel]
# 10                                         [Måneskin]
# 11                                     [Gjon's Tears]
# 12                       [Kayla Nicole, Taylor Girlz]
# 13                                             [SyKo]
# 14                                          [Lovejoy]
# 15                                           [Efendi]
# 16                                            [dhruv]
# 17                                         [Måneskin]
# 18                                             [Adie]
# 19                                         [THE ROOP]
# 20  [Tion Wayne, Russ Millions, ArrDee, E1 (3x3), ...
# 21                                  [Elena Tsagrinou]
# 22                                          [Lovejoy]
# 23                                         [Måneskin]
# 24                                            [Yahya]
# 25                                       [Daði Freyr]
# 26                                          [Lovejoy]
# 27                                        [NCT DREAM]
# 28                                          [ENHYPEN]
# 29          [Crissin, Totoy El Frio, Natan & Shander]
# 30                                   [Olivia Rodrigo]
# 31                                          [Destiny]
# 32                                       [Tai Verdes]
# 33                                          [Jendrik]
# 34                                         [Mahalini]
# 35                                              [VMZ]
# 36                                        [eAeon, RM]
# 37                                   [PinkPantheress]
# 38        [DJ GRZS, Mc Fazano, Mc Marofa, Mc Mero RF]
# 39                            [WILLOW, Travis Barker]
# 40                                         [Måneskin]
# 41                                          [Manizha]
# 42                                           [Shouse]
# 43                                       [Surf Curse]
# 44                                         [Måneskin]
# 45                [Mc Davi, Mc Pedrinho, Mc Don Juan]
# 46                                              [A36]
# 47                       [Phantogram, Future Islands]
# 48                                        [NCT DREAM]
# 49                                    [Doja Cat, SZA]

# %% [markdown]
# ### Post-Processing

# %%
def date_process(df):
    dates = [datetime.strptime(d, '%Y-%m-%d') for d in df["album, release_date"]]
    dates = pd.Series(dates)
    dates = dates.dt.date

    df["album, release_date, datetime"] = dates
    return df
df = date_process(df)

# %%
def date_today_diff(df):
    today = date.today()
    diff = [(today-df["album, release_date, datetime"][i]).days for i in range(len(top_tracks))]
    df["Release/Today Day difference"] = diff
    return df
df = date_today_diff(df)

# %% [markdown]
# ### Visualization

# %%
df[["Release/Today Day difference"]].plot.hist(bins=8);

# %%
album_counts = df["album, name"].value_counts()

threshold = 0

if max(album_counts) > np.median(album_counts):
    threshold = np.median(album_counts) + 1
elif min(album_counts) < np.median(album_counts):
    threshold = np.median(album_counts) - 1
else:
    threshold = np.median(album_counts)
    
    
less_threshold = album_counts < threshold
meet_threshold = album_counts >= threshold
sum(less_threshold)


OTHER_ = pd.Series([sum(less_threshold)], index=["OTHER_"])

top_albums = album_counts[meet_threshold].append(OTHER_)
top_albums_df = pd.DataFrame(top_albums)
top_albums_df = top_albums_df.rename(columns={0:"album, name"})

top_albums_df.plot.pie("album, name");

# %%
sns.catplot(data=df,
            x="album, len artists",
            y="track, popularity",
            jitter=True);

# %%
sns.distplot(a=df["track, popularity"], hist=True);

# %%
#sns.displot(df, x="track, popularity", hue="album, len artists")

# %%
sns.scatterplot(data = df,
                x="album, len available_markets",
               y="track, popularity",
               alpha=0.5);

# %%
jitter=0.1

sns.regplot(data=df,
           x="album, len available_markets",
           y="track, popularity",
           ci=None,
           x_jitter=jitter,
           scatter_kws={'alpha':0.5});

# %%
explicit = df[df["track, explicit"] == True]["track, popularity"]
sns.distplot(explicit, label="Explicit")
plt.axvline(np.mean(explicit),
            linestyle='solid',
            linewidth=1,
            color="blue",
            label="Explicit Mean")

not_explicit = df[df["track, explicit"] == False]["track, popularity"]
sns.distplot(not_explicit, label="Not Explicit")
plt.axvline(np.mean(not_explicit),
            linestyle='solid',
            linewidth=1,
            color="Red",
            label="Non-Explicit Mean")

plt.legend();

# %% [markdown]
# ### Main

# %%
def playlist_main(token, category="50_global_top"):
    #determine id that corresponds to category
    playlist_category_id = {
        "viral_50_global": "37i9dQZEVXbLiRSasKsNU9",
        "top_50_global": "37i9dQZEVXbMDoHDwVN2tF",
        
        "viral_50_usa": "37i9dQZEVXbKuaTI1Z1Afx",
        "top_50_usa": "37i9dQZEVXbLRQDuF5jeBp",
        
        "top_50_vietnam": "37i9dQZEVXbLdGSmz6xilI",
        
        "top_50_japan": "37i9dQZEVXbKXQ4mDTEBXq",
        
        "top_50_argentina": "37i9dQZEVXbMMy2roB9myp",
        
        "top_50_indonesia": "37i9dQZEVXbObFQZ3JLcXt",
        
        "top_50_india": "37i9dQZEVXbLZ52XmnySJg",
        
        "top_50_uk": "37i9dQZEVXbLnolsZ8PSNw",  #(has 2004)
        "top_50_spain": "37i9dQZEVXbNFJfN1Vw8d9",
        "top_50_australia": "37i9dQZEVXbJPcfkRz0wJ0", #(has 2004)
        "top_50_turkey": "37i9dQZEVXbIVYVBNw9D5K",
        "top_50_france": "37i9dQZEVXbIPWwFssbupI",
        "top_50_taiwan": "37i9dQZEVXbMnZEatlMSiu",
        "top_50_brazil": "37i9dQZEVXbMMy2roB9myp",
        "top_50_germany": "37i9dQZEVXbMMy2roB9myp"
        
        #"top_50_mexico": "37i9dQZEVXbO3qyFxbkOE1", #has a weird 1993 year
        #"50s_party": "37i9dQZF1DWSwFS0Z6E1ep" #has YEAR-MO
    }
    print(category)
    id_ = playlist_category_id.get(category, "ERROR")
    
    #create token   
    resp = requests.get(
        url = 'https://api.spotify.com/v1/playlists/' + id_,
        headers = {
            'Authorization': 'Bearer '+ token
        }
    )
    r = resp.json()
    
    tracks = r.get('tracks').get("items")
        
    #create dataframes
    df = pd.DataFrame()
    df = df_album(df, tracks)
    df = df_tracks(df, tracks)
    
    #date post-processing
    #display(df)
    df = date_process(df)
    df = date_today_diff(df)
    
    playlist_dict = {
        "category": category,
        "url": r.get("external_urls").get("spotify"),
        "name": r.get("name"),
        "followers": r.get("followers").get("total")
    }
    
    return playlist_dict, df

# %%
def playlist_visual(df):
    def hist(df, bins=8):
        df[["Release/Today Day difference"]].plot.hist(bins=bins);
        plt.title("The Difference between Release Date and Today")
        plt.xlabel("Days")
        plt.ylabel("Count")
        plt.show()
    def cat(df, jitter=True):
        sns.catplot(data=df,
            x="album, len artists",
            y="track, popularity",
            jitter=jitter);
        plt.title("Correlation between Album Artist Count and Track Popularity (Jittered)")
        plt.xlabel("Album Artist Count")
        plt.ylabel("Track Popularity")
        plt.show()
    def dist(df):
        sns.distplot(a=df["track, popularity"], hist=True);
        plt.axvline(np.mean(df["track, popularity"]),
                    linestyle='solid',
                    linewidth=1,
                    color="green")
        plt.axvline(np.median(df["track, popularity"]),
                    linestyle='solid',
                    linewidth=1,
                    color="red")
        plt.title("Distribution of Track Popularities")
        plt.xlabel("Track Popularity")
        plt.ylabel("Frequency")
        plt.show()
    def reg(df, jitter=0.2):
        sns.regplot(data=df,
                   x="album, len available_markets",
                   y="track, popularity",
                   ci=None,
                   x_jitter=jitter,
                   scatter_kws={'alpha':0.3});
        plt.title("Correlation between Album Market Availibility and Track Popularity (Jittered)")
        plt.xlabel("Number of Countries Album is Availible In")
        plt.ylabel("Track Popularity")
        plt.show();
    def pie(df):
        album_counts = df["album, name"].value_counts()

        #determine threshold
        threshold = 0
        if max(album_counts) > np.median(album_counts):
            threshold = np.median(album_counts) + 1
        elif min(album_counts) < np.median(album_counts):
            threshold = np.median(album_counts) - 1
        else:
            threshold = np.median(album_counts)

        #seperate into those that fail/meet threshold
        less_threshold = album_counts < threshold
        meet_threshold = album_counts >= threshold
        sum(less_threshold)

        #process the data
        OTHER_ = pd.Series([sum(less_threshold)], index=["OTHER_"])

        top_albums = album_counts[meet_threshold].append(OTHER_)
        top_albums_df = pd.DataFrame(top_albums)
        top_albums_df = top_albums_df.rename(columns={0:"album, name"})
        
        #determine exploding array
        explode = []
        for i in range(len(top_albums_df)):
            explode.append(top_albums_df.iloc[i]["album, name"] == max(album_counts))
        explode = pd.Series(explode)/7

        #plot the data
        plt.figure(figsize=(9, 7), dpi=80)
        plt.pie(top_albums_df["album, name"],
                labels=top_albums_df.index,
                counterclock=False,
                startangle=90,
                pctdistance=0.85,
                explode=explode);
        plt.title("Album Frequency Among Tracks")
        plt.show()
    def explicit(df):
        plt.figure(figsize=(7, 5), dpi=80)
        
        explicit = df[df["track, explicit"] == True]["track, popularity"]
        
        sns.distplot(explicit, label="Explicit",
                    hist=False)
        plt.axvline(np.mean(explicit),
                    linestyle='solid',
                    linewidth=1,
                    color="blue",
                    label="Explicit Mean")

        not_explicit = df[df["track, explicit"] == False]["track, popularity"]
        sns.distplot(not_explicit, label="Not Explicit",
                    hist=False)
        plt.axvline(np.mean(not_explicit),
                    linestyle='solid',
                    linewidth=1,
                    color="Red",
                    label="Non-Explicit Mean")
        
        plt.title("Track Popularity Distribution on Explicit-ness")
        plt.xlabel("Track Popularity")
        plt.ylabel("Frequency")
        plt.legend();
    
    hist(df)
    cat(df)
    dist(df)
    reg(df)
    pie(df)
    explicit(df);

# %%
TOKEN = "BQB96x-cxU25olOg8OdbaYGPpAu6DB6r9AEofd5qcPOrfaKbcYaHxyhnrpQGipZVxl14df3CH4IcCP3eXGKEiv2uAZ6RmLVIXU6hTFSaQbZk8Kf5RJCLnoH6yOI5jiBEnYH0hXahyrxJfzksXAckWyYmxQ_YR182MJiWOSwE"
playlist_dict, df_50 = playlist_main(token = TOKEN, category="top_50_taiwan")

playlist_visual(df_50)
# Out:
# top_50_taiwan
# 2021-06-02 01:46:25,280 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,286 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 39746 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,294 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20986 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,301 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 31429 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,312 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 38728 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,321 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 39746 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,333 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20986 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,339 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 31429 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,356 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36939 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,362 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27683 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,369 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20358 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,376 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24471 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,382 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33509 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,388 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26377 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,395 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,401 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28961 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,407 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36939 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,412 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27683 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,417 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20358 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,421 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24471 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,427 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 33509 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,432 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26377 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,439 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20284 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,443 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28961 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,450 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25705 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,454 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22825 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,458 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21205 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,466 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,472 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22290 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
#
# 2021-06-02 01:46:25,481 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25705 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,486 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22825 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,490 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21205 missing from current font.
#   font.set_text(s, 0, flags=flags)
# 2021-06-02 01:46:25,495 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29289 missing from current font.
#   font.set_text(s, 0, flags=flags)
#
# 2021-06-02 01:46:25,499 [13412] WARNING  py.warnings:110: [JupyterRequire] C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22290 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
playlist_dict
# Out:
# {'category': 'top_50_global',
#  'url': 'https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF',
#  'name': 'Top 50 - Global',
#  'followers': 16117208}

# %% [markdown]
# category = "viral_50_global"
# token=TOKEN
# playlist_category_id = {
#     "viral_50_global": "37i9dQZEVXbLiRSasKsNU9",
#     "top_50_global": "37i9dQZEVXbMDoHDwVN2tF",
#
#     "viral_50_usa": "37i9dQZEVXbKuaTI1Z1Afx",
#     "top_50_usa": "37i9dQZEVXbLRQDuF5jeBp",
#
#     "top_50_vietnam": "37i9dQZEVXbLdGSmz6xilI",
#
#     "top_50_japan": "37i9dQZEVXbKXQ4mDTEBXq",
#
#     "top_50_argentina": "37i9dQZEVXbMMy2roB9myp",
#
#     "top_50_indonesia": "37i9dQZEVXbObFQZ3JLcXt",
#
#     "top_50_india": "37i9dQZEVXbLZ52XmnySJg"
#
#     #"top_50_mexico": "37i9dQZEVXbO3qyFxbkOE1", #has a weird 1993 year
#     #"50s_party": "37i9dQZF1DWSwFS0Z6E1ep" #has YEAR-MO
# }
# print(category)
# id_ = playlist_category_id.get(category, "ERROR")
#
# #create token
# resp = requests.get(
#     url = 'https://api.spotify.com/v1/playlists/' + id_,
#     headers = {
#         'Authorization': 'Bearer '+ token
#     }
# )
# r = resp.json()
#
# tracks = r.get('tracks').get("items")

# %% [markdown]
# tracks[0].get("track").get("explicit")

# %% [markdown]
# TOKEN = 'BQDrbDT4kLhwctaiXijkqtYSh0-3T6MD03xre8sRq2EEzk-QipMkF0AefTKzt6fuQlIzharfpiY-SYa2bm77zcLYc4dUX2uL1h6VkCgaWScVokeAwe3exXp5hKm6iCEReUlz7sShaX7Rj0JYfHYLfaGlfBW4mItlVegJ90wx'
# df_50 = playlist_main(token = TOKEN, category="top")
# playlist_visual(df_50)

# %% [markdown]
# TOKEN = 'BQBR0Uls74aPKmCyi8ww5jyRiVVDnR3mNrYrzI-MLMDsgqDzOPUrE6IupyXKUZM7Ni7qkm7b5w0T-jOfApmEBYKY0aK3JvZCcCneZ0ZoVOi15ZEBJgMOPDX8-qd5YFxgwkonWgCf6-ycOdTgVrEP3ELzXtMvez4KIYG49vnt'
# BASE_URL = 'https://api.spotify.com/v1/'
# headers = {
#     'Authorization': 'Bearer '+ TOKEN
# }
#
# console = 'artists'
# _id = '2CIMQHirSU0MQqyYHq0eOx%2C57dN52uHvrHOxijzpIgu3E%2C1vCWHaC5f2uS3yhpwWbIA6'
#
#
#
# resp = requests.get(
#     url = 'https://api.spotify.com/v1/playlists/37i9dQZEVXbLiRSasKsNU9',#viral 50
#     #url = 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF',#top 50
#     headers = headers
# )
# r = resp.json()
# top_tracks = r.get('tracks').get("items")

# %% [markdown]
# url = r.get("external_urls").get("spotify")
# name = r.get("name")
# followers = r.get("followers").get("total")
#
#
# url, name, followers

# %% [markdown]
# https://open.spotify.com/playlist/37i9dQZEVXbLiRSasKsNU9

# %% [markdown]
# https://developer.spotify.com/console/get-playlist/?playlist_id=37i9dQZEVXbLiRSasKsNU9&market=&fields=&additional_types=

# %% [markdown]
# For all the playlists:
#
# https://open.spotify.com/search/top%2050/playlists
